# %% [markdown]
# <a href="https://colab.research.google.com/github/YoloA11000/Metodos-Numericos/blob/main/Modelos_estoc%C3%A1sticos.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# #Uso de números aleatorios

# %%
import random as rd
rd.random()
# Out:
# 0.10510743608070316

# %% [markdown]
# Ejercicio 1. Simular un volado

# %%
def volado():
  import random
  resultado = random.choice(['Cara', 'Cruz'])
  return resultado

# %%
def volado():
if rd.random() <= 0.5:
return "cara"
else:
return
